# %%
import requests
url = "https://www.linkedin.com/jobs/search/?currentJobId=3720730274&f_TPR=r86400&f_WT=2&geoId=92000000&location=Worldwide&origin=JOB_SEARCH_PAGE_JOB_FILTER&refresh=true&start=225"
response = requests.get(url)

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="d_jobs_guest_search" name="pageKey"/>
# <!-- --> <meta content="urlType=jserp_custom;emptyResult=false" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1545" data-browser-id="35640d36-afda-4aff-8b1a-1831f1a67716" data-call-tree-id="AAYRQgFBrcTbhoyf30BDTg==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;XmU1SGQhTmKn47wjM67yxw==" data-service-name="jobs-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/jobs/jobs-in-worldwide" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
# <script>
# ...
